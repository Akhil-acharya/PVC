# %%
import wfdb
import pandas as pd

def convert_beats_to_csv(record_name, output_csv):
    """
    Convert .hea, .atr, and .dat files to a .csv file with Time, signals, Annotation, and R-R Interval.

    Parameters:
    - record_name: Base name of the record (without extension).
    - output_csv: Path to save the output CSV file.
    """
    try:
        # Load the record and annotation
        record = wfdb.rdrecord(record_name)
        annotation = wfdb.rdann(record_name, 'atr')

        # Extract sampling frequency
        fs = record.fs

        # Identify available signals
        signal_names = record.sig_name
        print(f"Available signals in the record: {signal_names}")  # Debug statement

        # Define a priority list for required signals
        priority_signals = ["MLII", "II", "V5", "V4", "V2","V1"]

        # Select the first two available signals from the priority list
        selected_signals = [sig for sig in priority_signals if sig in signal_names][:2]
        if len(selected_signals) < 2:
            raise ValueError(f"Not enough signals found. Available signals: {signal_names}")

        # Extract signal indices and values
        signal_indices = {sig: signal_names.index(sig) for sig in selected_signals}
        signals = {sig: record.p_signal[:, idx] for sig, idx in signal_indices.items()}

        # Create a DataFrame for annotations
        annotations = pd.DataFrame({
            "Sample": annotation.sample,
            "Annotation": annotation.symbol
        })

        # Convert annotations to human-readable labels
        annotation_mapping = {
            "N": "Normal",  # Normal beat
            "V": "PVC",     # Premature ventricular contraction
            "A": "Atrial premature contraction",
            "L": "Left bundle branch block",
            "R": "Right bundle branch block",
            # Add other mappings if necessary
        }
        annotations["Annotation"] = annotations["Annotation"].map(annotation_mapping).fillna("Other")

        # Compute time values for each annotation sample
        annotations["Time"] = annotations["Sample"] / fs

        # Compute R-R Intervals (time difference between consecutive beats)
        annotations["R-R Interval"] = annotations["Time"].diff().fillna(0)

        # Extract signal values at annotation points
        for sig in selected_signals:
            annotations[sig] = annotations["Sample"].apply(lambda x: signals[sig][x])

        # Save the DataFrame to CSV
        annotations.to_csv(output_csv, index=False)

        # Display the summary of beats
        beat_counts = annotations["Annotation"].value_counts()
        print("Summary of beats:")
        print(beat_counts)
        print(f"Total beats: {len(annotations)}")

        # Print the first few rows of the CSV
        print("First few rows of the dataset:")
        print(annotations.head())

    except Exception as e:
        print(f"Error: {e}")

# Example usage
record_name = "208"  # Replace with the record's base name
output_csv = "208.csv"  # Output CSV file name
convert_beats_to_csv(record_name, output_csv)
# Out:
# Available signals in the record: ['MLII', 'V1']
# Summary of beats:
# Annotation
# Normal    1586
# PVC        992
# Other      462
# Name: count, dtype: int64
# Total beats: 3040
# First few rows of the dataset:
#    Sample Annotation      Time  R-R Interval   MLII     V1
# 0       9      Other  0.025000      0.000000 -0.145  0.220
# 1      46      Other  0.127778      0.102778  1.935 -0.395
# 2     209        PVC  0.580556      0.452778  1.705 -0.885
# 3     483     Normal  1.341667      0.761111  1.465 -0.040
# 4     697      Other  1.936111      0.594444  1.855 -1.050

# %%
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, Reshape, LSTM, Attention
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import wfdb
import pandas as pd
import pywt
from scipy.signal import hilbert

# Helper function to extract combined features (Wavelet, Hilbert, WVD)
def extract_combined_features(signal):
    # Wavelet Transform
    coeffs, _ = pywt.cwt(signal, scales=np.arange(1, 128), wavelet='morl')
    wavelet_features = np.abs(coeffs).mean(axis=0)

    # Hilbert Transform
    analytic_signal = hilbert(signal)
    amplitude_envelope = np.abs(analytic_signal)

    # FFT magnitude
    fft_magnitude = np.abs(np.fft.fft(signal))

    return np.concatenate([
        signal,  # Original signal
        wavelet_features,  # Wavelet features
        amplitude_envelope,  # Hilbert features
        fft_magnitude  # FFT magnitude
    ])

# Preprocess ECG data
def preprocess_data_with_combined_features(record_name, priority_signals, window_size=256):
    record = wfdb.rdrecord(record_name)
    annotation = wfdb.rdann(record_name, 'atr')
    signal_names = record.sig_name
    available_signals = [sig for sig in priority_signals if sig in signal_names][:1]

    if len(available_signals) < 1:
        raise ValueError("No matching signals found in the priority list.")

    signals = {sig: record.p_signal[:, signal_names.index(sig)] for sig in available_signals}
    features, labels = [], []

    for i, sample in enumerate(annotation.sample):
        start = max(0, sample - window_size // 2)
        end = min(len(record.p_signal), sample + window_size // 2)

        signal_window = signals[available_signals[0]][start:end]
        if len(signal_window) < window_size:
            signal_window = np.pad(signal_window, (0, window_size - len(signal_window)), 'constant')

        combined_features = extract_combined_features(signal_window)
        features.append(combined_features)
        labels.append(1 if annotation.symbol[i] == 'V' else 0)

    scaler = StandardScaler()
    features = scaler.fit_transform(features)

    return np.array(features), np.array(labels), annotation, signals[available_signals[0]]

# Helper function to plot a 30-second segment of the ECG signal
def plot_signal_with_pvc(signal, annotation, sample_rate, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify PVC beats within the selected window
    pvc_indices = [i for i, sym in enumerate(annotation.symbol) if sym == 'V']
    pvc_samples = [annotation.sample[i] for i in pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight PVC locations
    for pvc_sample in pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='red', linestyle='--', label="PVC" if pvc_sample == pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Visualize detected PVC beats
def visualize_detected_pvc_beats(signal, annotation, sample_rate, y_pred, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify detected PVC beats within the selected window
    detected_pvc_indices = np.where(y_pred == 1)[0]
    detected_pvc_samples = [annotation.sample[i] for i in detected_pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight detected PVC locations
    for pvc_sample in detected_pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='green', linestyle='--', label="Detected PVC" if pvc_sample == detected_pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with Detected PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Build optimized CNN-LSTM model
def build_optimized_cnn_lstm_model(input_shape):
    inputs = Input(shape=input_shape)

    # CNN layers
    x = Reshape((input_shape[0], 1))(inputs)
    x = Conv1D(64, kernel_size=3, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Conv1D(128, kernel_size=5, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)

    # LSTM layers with attention
    lstm_out = LSTM(128, return_sequences=True)(x)
    attention = Attention()([lstm_out, lstm_out])
    lstm_out = LSTM(64, return_sequences=False)(attention)

    # Dense layers
    x = Dense(256, activation='relu', kernel_regularizer='l2')(lstm_out)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(2, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Calculate additional metrics
def calculate_metrics(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    ppv = tp / (tp + fp)  # Positive Predictive Value
    npv = tn / (tn + fn)  # Negative Predictive Value
    fpr = fp / (fp + tn)  # False Positive Rate
    fnr = fn / (tp + fn)  # False Negative Rate
    fdr = fp / (tp + fp)  # False Discovery Rate
    f1_score = 2 * tp / (2 * tp + fp + fn)
    return sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score

# Main function
def main(record_name, priority_signals, output_csv="output.csv"):
    print("Preprocessing data...")
    features, labels, annotation, signal = preprocess_data_with_combined_features(record_name, priority_signals)

    print("Splitting data...")
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

    print("Building and training CNN-LSTM model...")
    model = build_optimized_cnn_lstm_model(input_shape=X_train.shape[1:])
    history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test),
                        class_weight=class_weights_dict)

    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Accuracy: {test_accuracy:.2f}")

    # Plot training and validation accuracy
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    print("Generating ROC curve...")
    y_pred_prob = model.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test[:, 1], y_pred_prob[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

    print("Calculating additional metrics...")
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_test, axis=1)

    sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score = calculate_metrics(y_true, y_pred)

    print(f"Sensitivity: {sensitivity:.2f}")
    print(f"Specificity: {specificity:.2f}")
    print(f"PPV (Precision): {ppv:.2f}")
    print(f"NPV: {npv:.2f}")
    print(f"FPR: {fpr:.2f}")
    print(f"FNR: {fnr:.2f}")
    print(f"FDR: {fdr:.2f}")
    print(f"F1 Score: {f1_score:.2f}")

    pvc_count = np.sum(labels)
    print(f"Total PVC Beats: {pvc_count}")
    print(f"Total R-R Peaks: {len(annotation.symbol)}")

    print("\nVisualizing 30-second ECG signal with PVCs highlighted...")
    plot_signal_with_pvc(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, window_length=30)

    # Visualize detected PVC beats
    print("Visualizing 30-second ECG signal with detected PVCs highlighted...")
    visualize_detected_pvc_beats(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, y_pred=y_pred, window_length=30)

# Example usage
record_name = "208"  # Replace with your record name
priority_signals = ["MLII", "II", "V5", "V4", "V2", "V1"]
main(record_name, priority_signals)
# Out:
# Preprocessing data...
# Splitting data...
# Building and training CNN-LSTM model...
# Epoch 1/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.9117 - loss: 1.1562 - val_accuracy: 0.6464 - val_loss: 1.3938
# Epoch 2/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6643s 180s/step - accuracy: 0.9631 - loss: 0.8242 - val_accuracy: 0.6464 - val_loss: 1.2360
# Epoch 3/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9797 - loss: 0.5787 - val_accuracy: 0.6464 - val_loss: 1.1355
# Epoch 4/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9799 - loss: 0.4290 - val_accuracy: 0.6464 - val_loss: 1.0952
# Epoch 5/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9898 - loss: 0.3254 - val_accuracy: 0.6464 - val_loss: 1.0216
# Epoch 6/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9823 - loss: 0.2755 - val_accuracy: 0.6464 - val_loss: 0.9964
# Epoch 7/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9896 - loss: 0.1932 - val_accuracy: 0.6464 - val_loss: 0.9785
# Epoch 8/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9921 - loss: 0.1506 - val_accuracy: 0.6464 - val_loss: 0.9596
# Epoch 9/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9918 - loss: 0.1249 - val_accuracy: 0.6480 - val_loss: 0.8792
# Epoch 10/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.9851 - loss: 0.1116 - val_accuracy: 0.7056 - val_loss: 0.4990
# Epoch 11/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.9894 - loss: 0.0908 - val_accuracy: 0.6859 - val_loss: 0.5412
# Epoch 12/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9904 - loss: 0.0738 - val_accuracy: 0.7484 - val_loss: 0.4266
# Epoch 13/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2815s 76s/step - accuracy: 0.9924 - loss: 0.0599 - val_accuracy: 0.9671 - val_loss: 0.1485
# Epoch 14/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3810s 103s/step - accuracy: 0.9972 - loss: 0.0389 - val_accuracy: 0.9967 - val_loss: 0.0588
# Epoch 15/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9876 - loss: 0.0477 - val_accuracy: 0.9951 - val_loss: 0.0397
# Epoch 16/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9947 - loss: 0.0343 - val_accuracy: 0.9803 - val_loss: 0.0496
# Epoch 17/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9916 - loss: 0.0309 - val_accuracy: 0.9967 - val_loss: 0.0368
# Epoch 18/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9976 - loss: 0.0219 - val_accuracy: 0.9852 - val_loss: 0.0427
# Epoch 19/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9921 - loss: 0.0325 - val_accuracy: 0.9868 - val_loss: 0.0392
# Epoch 20/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9942 - loss: 0.0209 - val_accuracy: 0.9918 - val_loss: 0.0276
# Epoch 21/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9955 - loss: 0.0165 - val_accuracy: 0.9901 - val_loss: 0.0236
# Epoch 22/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9946 - loss: 0.0247 - val_accuracy: 0.9803 - val_loss: 0.0488
# Epoch 23/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9992 - loss: 0.0110 - val_accuracy: 0.9786 - val_loss: 0.0916
# Epoch 24/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9919 - loss: 0.0277 - val_accuracy: 0.9786 - val_loss: 0.1024
# Epoch 25/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9952 - loss: 0.0206 - val_accuracy: 0.9852 - val_loss: 0.0659
# Epoch 26/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9983 - loss: 0.0112 - val_accuracy: 0.9901 - val_loss: 0.0295
# Epoch 27/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9975 - loss: 0.0114 - val_accuracy: 0.9901 - val_loss: 0.0279
# Epoch 28/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9979 - loss: 0.0103 - val_accuracy: 0.9836 - val_loss: 0.0526
# Epoch 29/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9974 - loss: 0.0121 - val_accuracy: 0.9901 - val_loss: 0.0311
# Epoch 30/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9983 - loss: 0.0093 - val_accuracy: 0.9951 - val_loss: 0.0171
# Test Accuracy: 1.00
# Generating ROC curve...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step
# Calculating additional metrics...
# Sensitivity: 1.00
# Specificity: 0.99
# PPV (Precision): 0.99
# NPV: 1.00
# FPR: 0.01
# FNR: 0.00
# FDR: 0.01
# F1 Score: 0.99
# Total PVC Beats: 992
# Total R-R Peaks: 3040
#
# Visualizing 30-second ECG signal with PVCs highlighted...
# Visualizing 30-second ECG signal with detected PVCs highlighted...

# %%
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, Reshape, LSTM, Attention
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import wfdb
import pandas as pd
import pywt
from scipy.signal import hilbert

# Helper function to extract combined features (Wavelet, Hilbert, WVD)
def extract_combined_features(signal):
    # Wavelet Transform
    coeffs, _ = pywt.cwt(signal, scales=np.arange(1, 128), wavelet='morl')
    wavelet_features = np.abs(coeffs).mean(axis=0)

    # Hilbert Transform
    analytic_signal = hilbert(signal)
    amplitude_envelope = np.abs(analytic_signal)

    # FFT magnitude
    fft_magnitude = np.abs(np.fft.fft(signal))

    return np.concatenate([
        signal,  # Original signal
        wavelet_features,  # Wavelet features
        amplitude_envelope,  # Hilbert features
        fft_magnitude  # FFT magnitude
    ])

# Preprocess ECG data
def preprocess_data_with_combined_features(record_name, priority_signals, window_size=256):
    record = wfdb.rdrecord(record_name)
    annotation = wfdb.rdann(record_name, 'atr')
    signal_names = record.sig_name
    available_signals = [sig for sig in priority_signals if sig in signal_names][:1]

    if len(available_signals) < 1:
        raise ValueError("No matching signals found in the priority list.")

    signals = {sig: record.p_signal[:, signal_names.index(sig)] for sig in available_signals}
    features, labels = [], []

    for i, sample in enumerate(annotation.sample):
        start = max(0, sample - window_size // 2)
        end = min(len(record.p_signal), sample + window_size // 2)

        signal_window = signals[available_signals[0]][start:end]
        if len(signal_window) < window_size:
            signal_window = np.pad(signal_window, (0, window_size - len(signal_window)), 'constant')

        combined_features = extract_combined_features(signal_window)
        features.append(combined_features)
        labels.append(1 if annotation.symbol[i] == 'V' else 0)

    scaler = StandardScaler()
    features = scaler.fit_transform(features)

    return np.array(features), np.array(labels), annotation, signals[available_signals[0]]

# Helper function to plot a 30-second segment of the ECG signal
def plot_signal_with_pvc(signal, annotation, sample_rate, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify PVC beats within the selected window
    pvc_indices = [i for i, sym in enumerate(annotation.symbol) if sym == 'V']
    pvc_samples = [annotation.sample[i] for i in pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight PVC locations
    for pvc_sample in pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='red', linestyle='--', label="PVC" if pvc_sample == pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Visualize detected PVC beats
def visualize_detected_pvc_beats(signal, annotation, sample_rate, y_pred, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify detected PVC beats within the selected window
    detected_pvc_indices = np.where(y_pred == 1)[0]
    detected_pvc_samples = [annotation.sample[i] for i in detected_pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight detected PVC locations
    for pvc_sample in detected_pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='green', linestyle='--', label="Detected PVC" if pvc_sample == detected_pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with Detected PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Build optimized CNN-LSTM model
def build_optimized_cnn_lstm_model(input_shape):
    inputs = Input(shape=input_shape)

    # CNN layers
    x = Reshape((input_shape[0], 1))(inputs)
    x = Conv1D(64, kernel_size=3, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Conv1D(128, kernel_size=5, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)

    # LSTM layers with attention
    lstm_out = LSTM(128, return_sequences=True)(x)
    attention = Attention()([lstm_out, lstm_out])
    lstm_out = LSTM(64, return_sequences=False)(attention)

    # Dense layers
    x = Dense(256, activation='relu', kernel_regularizer='l2')(lstm_out)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(2, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Calculate additional metrics
def calculate_metrics(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:", cm)
    if cm.size == 1:
        tn, fp, fn, tp = 0, 0, 0, cm[0, 0]
    else:
        tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    ppv = tp / (tp + fp) if (tp + fp) > 0 else 0  # Positive Predictive Value
    npv = tn / (tn + fn) if (tn + fn) > 0 else 0  # Negative Predictive Value
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  # False Positive Rate
    fnr = fn / (tp + fn) if (tp + fn) > 0 else 0  # False Negative Rate
    fdr = fp / (tp + fp) if (tp + fp) > 0 else 0  # False Discovery Rate
    f1_score = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) > 0 else 0
    return sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score

# Main function
def main(record_name, priority_signals, output_csv="output.csv"):
    print("Preprocessing data...")
    features, labels, annotation, signal = preprocess_data_with_combined_features(record_name, priority_signals)

    print("Splitting data...")
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Ensure labels are one-hot encoded
    y_train = to_categorical(y_train, num_classes=2)
    y_test = to_categorical(y_test, num_classes=2)

    class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

    print("Building and training CNN-LSTM model...")
    model = build_optimized_cnn_lstm_model(input_shape=X_train.shape[1:])
    history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test),
                        class_weight=class_weights_dict)

    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Accuracy: {test_accuracy:.2f}")

    # Plot training and validation accuracy
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    print("Generating ROC curve...")
    y_pred_prob = model.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test[:, 1], y_pred_prob[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

    print("Calculating additional metrics...")
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_test, axis=1)

    sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score = calculate_metrics(y_true, y_pred)

    print(f"Sensitivity: {sensitivity:.2f}")
    print(f"Specificity: {specificity:.2f}")
    print(f"PPV (Precision): {ppv:.2f}")
    print(f"NPV: {npv:.2f}")
    print(f"FPR: {fpr:.2f}")
    print(f"FNR: {fnr:.2f}")
    print(f"FDR: {fdr:.2f}")
    print(f"F1 Score: {f1_score:.2f}")

    pvc_count = np.sum(labels)
    print(f"Total PVC Beats: {pvc_count}")
    print(f"Total R-R Peaks: {len(annotation.symbol)}")

    print("\nVisualizing 30-second ECG signal with PVCs highlighted...")
    plot_signal_with_pvc(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, window_length=30)

    # Visualize detected PVC beats
    print("Visualizing 30-second ECG signal with detected PVCs highlighted...")
    visualize_detected_pvc_beats(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, y_pred=y_pred, window_length=30)

# Example usage
record_name = "102"  # Replace with your record name
priority_signals = ["MLII", "II", "V5", "V4", "V2", "V1"]
main(record_name, priority_signals)
# Out:
# Preprocessing data...
# Splitting data...
# Building and training CNN-LSTM model...
# Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5984 - loss: 2.2775 - val_accuracy: 0.9954 - val_loss: 1.3946
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.7382 - loss: 1.1853 - val_accuracy: 1.0000 - val_loss: 1.1492
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8583 - loss: 1.0081 - val_accuracy: 1.0000 - val_loss: 0.9476
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9438 - loss: 2.0828 - val_accuracy: 1.0000 - val_loss: 0.8994
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9214 - loss: 0.9135 - val_accuracy: 1.0000 - val_loss: 0.8940
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9827 - loss: 0.7299 - val_accuracy: 1.0000 - val_loss: 0.8505
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9879 - loss: 0.6840 - val_accuracy: 1.0000 - val_loss: 0.7940
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9964 - loss: 0.6359 - val_accuracy: 1.0000 - val_loss: 0.7546
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9985 - loss: 0.5994 - val_accuracy: 1.0000 - val_loss: 0.7134
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9959 - loss: 0.5862 - val_accuracy: 1.0000 - val_loss: 0.6682
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9991 - loss: 0.5487 - val_accuracy: 1.0000 - val_loss: 0.6063
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9999 - loss: 0.5278 - val_accuracy: 1.0000 - val_loss: 0.5693
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9994 - loss: 0.5109 - val_accuracy: 1.0000 - val_loss: 0.5348
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 95s 3s/step - accuracy: 0.9986 - loss: 0.4928 - val_accuracy: 1.0000 - val_loss: 0.5017
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9984 - loss: 0.4784 - val_accuracy: 1.0000 - val_loss: 0.4677
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 1.0000 - loss: 0.4628 - val_accuracy: 1.0000 - val_loss: 0.4505
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.4491 - val_accuracy: 1.0000 - val_loss: 0.4378
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 1.0000 - loss: 0.4368 - val_accuracy: 1.0000 - val_loss: 0.4263
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.4245 - val_accuracy: 1.0000 - val_loss: 0.4144
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 1.0000 - loss: 0.4135 - val_accuracy: 1.0000 - val_loss: 0.4038
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 1.0000 - loss: 0.4026 - val_accuracy: 1.0000 - val_loss: 0.3955
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.3945 - val_accuracy: 1.0000 - val_loss: 0.3845
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 1.0000 - loss: 0.3832 - val_accuracy: 1.0000 - val_loss: 0.3750
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.3734 - val_accuracy: 1.0000 - val_loss: 0.3655
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 1.0000 - loss: 0.3644 - val_accuracy: 1.0000 - val_loss: 0.3567
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 1.0000 - loss: 0.3553 - val_accuracy: 1.0000 - val_loss: 0.3479
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 1.0000 - loss: 0.3461 - val_accuracy: 1.0000 - val_loss: 0.3397
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 1.0000 - loss: 0.3376 - val_accuracy: 1.0000 - val_loss: 0.3316
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 1.0000 - loss: 0.3294 - val_accuracy: 1.0000 - val_loss: 0.3236
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 1.0000 - loss: 0.3213 - val_accuracy: 1.0000 - val_loss: 0.3159
# Test Accuracy: 1.00
# Generating ROC curve...
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step
# C:\Python 3.12\Lib\site-packages\sklearn\metrics\_ranking.py:1180: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Calculating additional metrics...
# Confusion Matrix: [[439]]
# Sensitivity: 1.00
# Specificity: 0.00
# PPV (Precision): 1.00
# NPV: 0.00
# FPR: 0.00
# FNR: 0.00
# FDR: 0.00
# F1 Score: 1.00
# Total PVC Beats: 4
# Total R-R Peaks: 2192
#
# Visualizing 30-second ECG signal with PVCs highlighted...
# C:\Python 3.12\Lib\site-packages\sklearn\metrics\_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Visualizing 30-second ECG signal with detected PVCs highlighted...

# %%
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, Reshape, LSTM, Attention
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import wfdb
import pandas as pd
import pywt
from scipy.signal import hilbert

# Helper function to extract combined features (Wavelet, Hilbert, WVD)
def extract_combined_features(signal):
    # Wavelet Transform
    coeffs, _ = pywt.cwt(signal, scales=np.arange(1, 128), wavelet='morl')
    wavelet_features = np.abs(coeffs).mean(axis=0)

    # Hilbert Transform
    analytic_signal = hilbert(signal)
    amplitude_envelope = np.abs(analytic_signal)

    # FFT magnitude
    fft_magnitude = np.abs(np.fft.fft(signal))

    return np.concatenate([
        signal,  # Original signal
        wavelet_features,  # Wavelet features
        amplitude_envelope,  # Hilbert features
        fft_magnitude  # FFT magnitude
    ])

# Preprocess ECG data
def preprocess_data_with_combined_features(record_name, priority_signals, window_size=256):
    record = wfdb.rdrecord(record_name)
    annotation = wfdb.rdann(record_name, 'atr')
    signal_names = record.sig_name
    available_signals = [sig for sig in priority_signals if sig in signal_names][:1]

    if len(available_signals) < 1:
        raise ValueError("No matching signals found in the priority list.")

    signals = {sig: record.p_signal[:, signal_names.index(sig)] for sig in available_signals}
    features, labels = [], []

    for i, sample in enumerate(annotation.sample):
        start = max(0, sample - window_size // 2)
        end = min(len(record.p_signal), sample + window_size // 2)

        signal_window = signals[available_signals[0]][start:end]
        if len(signal_window) < window_size:
            signal_window = np.pad(signal_window, (0, window_size - len(signal_window)), 'constant')

        combined_features = extract_combined_features(signal_window)
        features.append(combined_features)
        labels.append(1 if annotation.symbol[i] == 'V' else 0)

    scaler = StandardScaler()
    features = scaler.fit_transform(features)

    return np.array(features), np.array(labels), annotation, signals[available_signals[0]]

# Helper function to plot a 30-second segment of the ECG signal
def plot_signal_with_pvc(signal, annotation, sample_rate, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify PVC beats within the selected window
    pvc_indices = [i for i, sym in enumerate(annotation.symbol) if sym == 'V']
    pvc_samples = [annotation.sample[i] for i in pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight PVC locations
    for pvc_sample in pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='red', linestyle='--', label="PVC" if pvc_sample == pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Visualize detected PVC beats
def visualize_detected_pvc_beats(signal, annotation, sample_rate, y_pred, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify detected PVC beats within the selected window
    detected_pvc_indices = np.where(y_pred == 1)[0]
    detected_pvc_samples = [annotation.sample[i] for i in detected_pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight detected PVC locations
    for pvc_sample in detected_pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='green', linestyle='--', label="Detected PVC" if pvc_sample == detected_pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with Detected PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Build optimized CNN-LSTM model
def build_optimized_cnn_lstm_model(input_shape):
    inputs = Input(shape=input_shape)

    # CNN layers
    x = Reshape((input_shape[0], 1))(inputs)
    x = Conv1D(64, kernel_size=3, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Conv1D(128, kernel_size=5, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)

    # LSTM layers with attention
    lstm_out = LSTM(128, return_sequences=True)(x)
    attention = Attention()([lstm_out, lstm_out])
    lstm_out = LSTM(64, return_sequences=False)(attention)

    # Dense layers
    x = Dense(256, activation='relu', kernel_regularizer='l2')(lstm_out)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(2, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Calculate additional metrics
def calculate_metrics(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:", cm)
    if cm.size == 1:
        tn, fp, fn, tp = 0, 0, 0, cm[0, 0]
    else:
        tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    ppv = tp / (tp + fp) if (tp + fp) > 0 else 0  # Positive Predictive Value
    npv = tn / (tn + fn) if (tn + fn) > 0 else 0  # Negative Predictive Value
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  # False Positive Rate
    fnr = fn / (tp + fn) if (tp + fn) > 0 else 0  # False Negative Rate
    fdr = fp / (tp + fp) if (tp + fp) > 0 else 0  # False Discovery Rate
    f1_score = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) > 0 else 0
    return sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score

# Main function
def main(record_name, priority_signals, output_csv="output.csv"):
    print("Preprocessing data...")
    features, labels, annotation, signal = preprocess_data_with_combined_features(record_name, priority_signals)

    print("Splitting data...")
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Ensure labels are one-hot encoded
    y_train = to_categorical(y_train, num_classes=2)
    y_test = to_categorical(y_test, num_classes=2)

    class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

    print("Building and training CNN-LSTM model...")
    model = build_optimized_cnn_lstm_model(input_shape=X_train.shape[1:])
    history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test),
                        class_weight=class_weights_dict)

    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Accuracy: {test_accuracy:.2f}")

    # Plot training and validation accuracy
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    print("Generating ROC curve...")
    y_pred_prob = model.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test[:, 1], y_pred_prob[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

    print("Calculating additional metrics...")
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_test, axis=1)

    sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score = calculate_metrics(y_true, y_pred)

    print(f"Sensitivity: {sensitivity:.2f}")
    print(f"Specificity: {specificity:.2f}")
    print(f"PPV (Precision): {ppv:.2f}")
    print(f"NPV: {npv:.2f}")
    print(f"FPR: {fpr:.2f}")
    print(f"FNR: {fnr:.2f}")
    print(f"FDR: {fdr:.2f}")
    print(f"F1 Score: {f1_score:.2f}")

    pvc_count = np.sum(labels)
    print(f"Total PVC Beats: {pvc_count}")
    print(f"Total R-R Peaks: {len(annotation.symbol)}")

    print("\nVisualizing 30-second ECG signal with PVCs highlighted...")
    plot_signal_with_pvc(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, window_length=30)

    # Visualize detected PVC beats
    print("Visualizing 30-second ECG signal with detected PVCs highlighted...")
    visualize_detected_pvc_beats(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, y_pred=y_pred, window_length=30)

# Example usage
record_name = "210"  # Replace with your record name
priority_signals = ["MLII", "II", "V5", "V4", "V2", "V1"]
main(record_name, priority_signals)
# Out:
# Preprocessing data...
# Splitting data...
# Building and training CNN-LSTM model...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.6922 - loss: 1.6187 - val_accuracy: 0.9385 - val_loss: 1.3332
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.8725 - loss: 1.1649 - val_accuracy: 0.9385 - val_loss: 1.0593
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9207 - loss: 0.9185 - val_accuracy: 0.9385 - val_loss: 0.8949
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9087 - loss: 0.8365 - val_accuracy: 0.9385 - val_loss: 0.7972
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9358 - loss: 0.6913 - val_accuracy: 0.9385 - val_loss: 0.7112
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9152 - loss: 0.7576 - val_accuracy: 0.9385 - val_loss: 0.6191
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9310 - loss: 0.6116 - val_accuracy: 0.9385 - val_loss: 0.5634
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9636 - loss: 0.4718 - val_accuracy: 0.9367 - val_loss: 0.5291
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9667 - loss: 0.4274 - val_accuracy: 0.9385 - val_loss: 0.4806
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9533 - loss: 0.4125 - val_accuracy: 0.9385 - val_loss: 0.4417
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9523 - loss: 0.4140 - val_accuracy: 0.9385 - val_loss: 0.4028
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9746 - loss: 0.3010 - val_accuracy: 0.9385 - val_loss: 0.3724
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9870 - loss: 0.2560 - val_accuracy: 0.9497 - val_loss: 0.3137
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9879 - loss: 0.2215 - val_accuracy: 0.9572 - val_loss: 0.2736
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9872 - loss: 0.2154 - val_accuracy: 0.9572 - val_loss: 0.2569
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9875 - loss: 0.1886 - val_accuracy: 0.9572 - val_loss: 0.2556
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9906 - loss: 0.1636 - val_accuracy: 0.9721 - val_loss: 0.2102
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9794 - loss: 0.1727 - val_accuracy: 0.9758 - val_loss: 0.1758
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9889 - loss: 0.1433 - val_accuracy: 0.9739 - val_loss: 0.1895
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9833 - loss: 0.1303 - val_accuracy: 0.9758 - val_loss: 0.1600
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9941 - loss: 0.1059 - val_accuracy: 0.9832 - val_loss: 0.1534
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9991 - loss: 0.0880 - val_accuracy: 0.9795 - val_loss: 0.1544
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9958 - loss: 0.0835 - val_accuracy: 0.9572 - val_loss: 0.2038
# Epoch 24/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9929 - loss: 0.0788 - val_accuracy: 0.9758 - val_loss: 0.1634
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9897 - loss: 0.0923 - val_accuracy: 0.9609 - val_loss: 0.1951
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9900 - loss: 0.0793 - val_accuracy: 0.9702 - val_loss: 0.1364
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9912 - loss: 0.0708 - val_accuracy: 0.9683 - val_loss: 0.1252
# Epoch 28/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9945 - loss: 0.0570 - val_accuracy: 0.9851 - val_loss: 0.1058
# Epoch 29/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9975 - loss: 0.0428 - val_accuracy: 0.9832 - val_loss: 0.1186
# Epoch 30/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9941 - loss: 0.0414 - val_accuracy: 0.9851 - val_loss: 0.1020
# Test Accuracy: 0.99
# Generating ROC curve...
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 331ms/step
# Calculating additional metrics...
# Confusion Matrix: [[498   6]
#  [  2  31]]
# Sensitivity: 0.94
# Specificity: 0.99
# PPV (Precision): 0.84
# NPV: 1.00
# FPR: 0.01
# FNR: 0.06
# FDR: 0.16
# F1 Score: 0.89
# Total PVC Beats: 194
# Total R-R Peaks: 2685
#
# Visualizing 30-second ECG signal with PVCs highlighted...
# Visualizing 30-second ECG signal with detected PVCs highlighted...

# %%
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, Reshape, LSTM, Attention
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import wfdb
import pandas as pd
import pywt
from scipy.signal import hilbert

# Helper function to extract combined features (Wavelet, Hilbert, WVD)
def extract_combined_features(signal):
    # Wavelet Transform
    coeffs, _ = pywt.cwt(signal, scales=np.arange(1, 128), wavelet='morl')
    wavelet_features = np.abs(coeffs).mean(axis=0)

    # Hilbert Transform
    analytic_signal = hilbert(signal)
    amplitude_envelope = np.abs(analytic_signal)

    # FFT magnitude
    fft_magnitude = np.abs(np.fft.fft(signal))

    return np.concatenate([
        signal,  # Original signal
        wavelet_features,  # Wavelet features
        amplitude_envelope,  # Hilbert features
        fft_magnitude  # FFT magnitude
    ])

# Preprocess ECG data
def preprocess_data_with_combined_features(record_name, priority_signals, window_size=256):
    record = wfdb.rdrecord(record_name)
    annotation = wfdb.rdann(record_name, 'atr')
    signal_names = record.sig_name
    available_signals = [sig for sig in priority_signals if sig in signal_names][:1]

    if len(available_signals) < 1:
        raise ValueError("No matching signals found in the priority list.")

    signals = {sig: record.p_signal[:, signal_names.index(sig)] for sig in available_signals}
    features, labels = [], []

    for i, sample in enumerate(annotation.sample):
        start = max(0, sample - window_size // 2)
        end = min(len(record.p_signal), sample + window_size // 2)

        signal_window = signals[available_signals[0]][start:end]
        if len(signal_window) < window_size:
            signal_window = np.pad(signal_window, (0, window_size - len(signal_window)), 'constant')

        combined_features = extract_combined_features(signal_window)
        features.append(combined_features)
        labels.append(1 if annotation.symbol[i] == 'V' else 0)

    scaler = StandardScaler()
    features = scaler.fit_transform(features)

    return np.array(features), np.array(labels), annotation, signals[available_signals[0]]

# Helper function to plot a 30-second segment of the ECG signal
def plot_signal_with_pvc(signal, annotation, sample_rate, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify PVC beats within the selected window
    pvc_indices = [i for i, sym in enumerate(annotation.symbol) if sym == 'V']
    pvc_samples = [annotation.sample[i] for i in pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight PVC locations
    for pvc_sample in pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='red', linestyle='--', label="PVC" if pvc_sample == pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Visualize detected PVC beats
def visualize_detected_pvc_beats(signal, annotation, sample_rate, y_pred, window_length=30):
    plt.figure(figsize=(15, 5))
    time = np.linspace(0, len(signal) / sample_rate, len(signal))

    # Identify detected PVC beats within the selected window
    detected_pvc_indices = np.where(y_pred == 1)[0]
    detected_pvc_samples = [annotation.sample[i] for i in detected_pvc_indices]

    # Plot the signal
    plt.plot(time, signal, label="ECG Signal", color='blue')

    # Highlight detected PVC locations
    for pvc_sample in detected_pvc_samples:
        pvc_time = pvc_sample / sample_rate
        if pvc_time <= window_length:  # Highlight PVCs within the first 30 seconds
            plt.axvline(pvc_time, color='green', linestyle='--', label="Detected PVC" if pvc_sample == detected_pvc_samples[0] else "")

    plt.xlim(0, window_length)
    plt.title(f"30-Second ECG Segment with Detected PVC Beats Highlighted")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()

# Build optimized CNN-LSTM model
def build_optimized_cnn_lstm_model(input_shape):
    inputs = Input(shape=input_shape)

    # CNN layers
    x = Reshape((input_shape[0], 1))(inputs)
    x = Conv1D(64, kernel_size=3, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Conv1D(128, kernel_size=5, activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=2)(x)

    # LSTM layers with attention
    lstm_out = LSTM(128, return_sequences=True)(x)
    attention = Attention()([lstm_out, lstm_out])
    lstm_out = LSTM(64, return_sequences=False)(attention)

    # Dense layers
    x = Dense(256, activation='relu', kernel_regularizer='l2')(lstm_out)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(2, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Calculate additional metrics
def calculate_metrics(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:", cm)
    if cm.size == 1:
        tn, fp, fn, tp = 0, 0, 0, cm[0, 0]
    else:
        tn, fp, fn, tp = cm.ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    ppv = tp / (tp + fp) if (tp + fp) > 0 else 0  # Positive Predictive Value
    npv = tn / (tn + fn) if (tn + fn) > 0 else 0  # Negative Predictive Value
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0  # False Positive Rate
    fnr = fn / (tp + fn) if (tp + fn) > 0 else 0  # False Negative Rate
    fdr = fp / (tp + fp) if (tp + fp) > 0 else 0  # False Discovery Rate
    f1_score = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) > 0 else 0
    return sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score

# Main function
def main(record_name, priority_signals, output_csv="output.csv"):
    print("Preprocessing data...")
    features, labels, annotation, signal = preprocess_data_with_combined_features(record_name, priority_signals)

    print("Splitting data...")
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Ensure labels are one-hot encoded
    y_train = to_categorical(y_train, num_classes=2)
    y_test = to_categorical(y_test, num_classes=2)

    class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

    print("Building and training CNN-LSTM model...")
    model = build_optimized_cnn_lstm_model(input_shape=X_train.shape[1:])
    history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test),
                        class_weight=class_weights_dict)

    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Accuracy: {test_accuracy:.2f}")

    # Plot training and validation accuracy
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    print("Generating ROC curve...")
    y_pred_prob = model.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test[:, 1], y_pred_prob[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

    print("Calculating additional metrics...")
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = np.argmax(y_test, axis=1)

    sensitivity, specificity, ppv, npv, fpr, fnr, fdr, f1_score = calculate_metrics(y_true, y_pred)

    print(f"Sensitivity: {sensitivity:.2f}")
    print(f"Specificity: {specificity:.2f}")
    print(f"PPV (Precision): {ppv:.2f}")
    print(f"NPV: {npv:.2f}")
    print(f"FPR: {fpr:.2f}")
    print(f"FNR: {fnr:.2f}")
    print(f"FDR: {fdr:.2f}")
    print(f"F1 Score: {f1_score:.2f}")

    pvc_count = np.sum(labels)
    print(f"Total PVC Beats: {pvc_count}")
    print(f"Total R-R Peaks: {len(annotation.symbol)}")

    print("\nVisualizing 30-second ECG signal with PVCs highlighted...")
    plot_signal_with_pvc(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, window_length=30)

    # Visualize detected PVC beats
    print("Visualizing 30-second ECG signal with detected PVCs highlighted...")
    visualize_detected_pvc_beats(signal, annotation, sample_rate=wfdb.rdrecord(record_name).fs, y_pred=y_pred, window_length=30)

# Example usage
record_name = "208"  # Replace with your record name
priority_signals = ["MLII", "II", "V5", "V4", "V2", "V1"]
main(record_name, priority_signals)
# Out:
# Preprocessing data...
# Splitting data...
# Building and training CNN-LSTM model...
# Epoch 1/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9213 - loss: 1.1657 - val_accuracy: 0.6464 - val_loss: 1.3878
# Epoch 2/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9751 - loss: 0.7651 - val_accuracy: 0.6464 - val_loss: 1.1764
# Epoch 3/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9786 - loss: 0.5789 - val_accuracy: 0.6464 - val_loss: 1.0584
# Epoch 4/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9869 - loss: 0.4211 - val_accuracy: 0.6464 - val_loss: 0.9700
# Epoch 5/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9873 - loss: 0.3132 - val_accuracy: 0.6464 - val_loss: 0.8675
# Epoch 6/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9885 - loss: 0.2397 - val_accuracy: 0.6464 - val_loss: 0.8655
# Epoch 7/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9878 - loss: 0.1882 - val_accuracy: 0.6464 - val_loss: 0.8449
# Epoch 8/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9900 - loss: 0.1478 - val_accuracy: 0.6464 - val_loss: 0.8168
# Epoch 9/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9859 - loss: 0.1408 - val_accuracy: 0.6480 - val_loss: 0.5829
# Epoch 10/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9954 - loss: 0.0891 - val_accuracy: 0.9326 - val_loss: 0.2692
# Epoch 11/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9958 - loss: 0.0699 - val_accuracy: 0.7451 - val_loss: 0.4838
# Epoch 12/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9959 - loss: 0.0553 - val_accuracy: 0.9934 - val_loss: 0.0899
# Epoch 13/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9940 - loss: 0.0505 - val_accuracy: 0.9901 - val_loss: 0.0879
# Epoch 14/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9911 - loss: 0.0465 - val_accuracy: 0.9260 - val_loss: 0.1858
# Epoch 15/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9935 - loss: 0.0394 - val_accuracy: 0.9951 - val_loss: 0.0467
# Epoch 16/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9917 - loss: 0.0337 - val_accuracy: 0.9819 - val_loss: 0.0778
# Epoch 17/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9968 - loss: 0.0220 - val_accuracy: 0.9901 - val_loss: 0.0273
# Epoch 18/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9979 - loss: 0.0164 - val_accuracy: 0.9951 - val_loss: 0.0246
# Epoch 19/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9960 - loss: 0.0206 - val_accuracy: 0.9868 - val_loss: 0.0552
# Epoch 20/30
# 32/38 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9937 - loss: 0.0164
